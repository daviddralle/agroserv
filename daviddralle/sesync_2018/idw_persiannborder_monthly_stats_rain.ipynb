# %%
import rasterio
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import datetime
import glob as glob
import datetime
import scipy
import sys
import os
import geopandas as gp
import statsmodels.api as sm
from linearmodels.panel import PanelOLS
# import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Rainfall dataset
#
# We use the rainfall dataset produced by Levy et al. (2017):
#
# Levy, M. C. (2017). Curated rain and flow data for the Brazilian rainforest-savanna transition zone, HydroShare, http://www.hydroshare.org/resource/e82e66572b444fc5b6bf16f88f911f77
#
# The data is interpolated using each day's active rain gauge data. Interpolations were done on a 0.25° resolution grid; the IDW parameter was set to 2 (default). The maximum interpolation distance (radius) was 1000m. The dataset was then sampled at all 5000 datapoints in `./data/sesync2018_points.geojson`, which were randomly generated (avoiding 'artificial surfaces' using GlobCover 2009, a global land cover map available in Google Earth Engine) within the Amazon and Cerrado biomes (note: some points were discarded because the rainfall dataset does not entirely cover the extent of the Amazon and Cerrado biomes).

# %%
df = pd.read_csv('./data/sesync2018_points_rainIdw.csv', parse_dates=True, index_col=0)

# %%
rainfall_threshold = 2.0
# get frequency of rainfall occurence
GBL=df.groupby([(df.index.year),(df.index.month)]).apply(
      lambda x: np.sum(x>rainfall_threshold)/float(len(x))
)

    
GBA=df.groupby([(df.index.year),(df.index.month)]).apply(
    lambda x: np.mean(x[x>rainfall_threshold]) 
)

# get lambdas pre/post treatment
pre = [1980, 1990]
post = [2004, 2014]

# %%
# read forest loss data
loss = pd.read_csv('data/hansen/loss.csv')
loss['id'] = loss['id'].astype(str)


GBLpre = GBL.loc[pre[0]:pre[1]].groupby(level=[1]).mean().T
GBLpre['id'] = GBLpre.index
GBLpre['post'] = 0
GBLpre = GBLpre.merge(loss, left_on='id', right_on='id', how='left'
                      ).melt(id_vars=['id','post', 'treated'], value_name='L', var_name='month')


GBLpost = GBL.loc[post[0]:post[1]].groupby(level=[1]).mean().T
GBLpost['id'] = GBLpost.index
GBLpost['post'] = 1
GBLpost = GBLpost.merge(loss, left_on='id', right_on='id', how='left'
                       ).melt(id_vars=['id','post', 'treated'], value_name='L', var_name='month')
tofit = pd.concat([GBLpost, GBLpre])
x1 = tofit.post.values
x2 = tofit.treated.values
tofit['treatmentstatus'] = 0
tofit['treatmentstatus'] = x2*x1
tofit = tofit.set_index(['id', 'post'])


for g in tofit.groupby('month'):
    mi_data = pd.DataFrame(g[1])
    exog_vars = ['treatmentstatus']
    exog = sm.add_constant(mi_data[exog_vars])
    mod = PanelOLS(mi_data.L, exog, entity_effects=True, time_effects=True)
    print('For month %s \n'%(str(g[0])))
    print(mod.fit())
# Out:
# For month 1
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0034
# Estimator:                   PanelOLS   R-squared (Between):              0.0015
# No. Observations:                7824   R-squared (Within):               0.0008
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0014
# Time:                        17:14:27   Log-likelihood                 1.384e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      13.218
# Entities:                        3912   P-value                           0.0003
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             13.218
#                                         P-value                           0.0003
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.8939     0.0007     1283.8     0.0000      0.8925      0.8953
# treatmentstatus    -0.0158     0.0043    -3.6356     0.0003     -0.0243     -0.0073
# ===================================================================================
#
# F-test for Poolability: 5.8301
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 2
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0034
# Estimator:                   PanelOLS   R-squared (Between):             -0.0012
# No. Observations:                7824   R-squared (Within):              -0.0062
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0019
# Time:                        17:14:27   Log-likelihood                 1.388e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      13.451
# Entities:                        3912   P-value                           0.0002
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             13.451
#                                         P-value                           0.0002
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.9001     0.0007     1298.1     0.0000      0.8987      0.9014
# treatmentstatus    -0.0159     0.0043    -3.6676     0.0002     -0.0244     -0.0074
# ===================================================================================
#
# F-test for Poolability: 6.4095
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 3
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0045
# Estimator:                   PanelOLS   R-squared (Between):             -0.0011
# No. Observations:                7824   R-squared (Within):              -0.0049
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0016
# Time:                        17:14:28   Log-likelihood                 1.294e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      17.655
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             17.655
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.8868     0.0008     1134.2     0.0000      0.8853      0.8883
# treatmentstatus    -0.0205     0.0049    -4.2017     0.0000     -0.0301     -0.0109
# ===================================================================================
#
# F-test for Poolability: 6.6877
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 4
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0053
# Estimator:                   PanelOLS   R-squared (Between):              0.0010
# No. Observations:                7824   R-squared (Within):               0.0006
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0010
# Time:                        17:14:29   Log-likelihood                 1.267e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      20.967
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             20.967
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.7736     0.0008     956.80     0.0000      0.7721      0.7752
# treatmentstatus    -0.0231     0.0051    -4.5790     0.0000     -0.0330     -0.0132
# ===================================================================================
#
# F-test for Poolability: 18.727
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 5
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0029
# Estimator:                   PanelOLS   R-squared (Between):              0.0017
# No. Observations:                7824   R-squared (Within):              -0.0048
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0015
# Time:                        17:14:29   Log-likelihood                 1.187e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      11.368
# Entities:                        3912   P-value                           0.0008
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             11.368
#                                         P-value                           0.0008
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.5494     0.0009     613.55     0.0000      0.5476      0.5511
# treatmentstatus    -0.0189     0.0056    -3.3716     0.0008     -0.0298     -0.0079
# ===================================================================================
#
# F-test for Poolability: 35.184
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 6
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0146
# Estimator:                   PanelOLS   R-squared (Between):              0.0039
# No. Observations:                7824   R-squared (Within):              -0.0040
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0038
# Time:                        17:14:30   Log-likelihood                 1.454e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      57.823
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             57.823
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.3519     0.0006     552.78     0.0000      0.3506      0.3531
# treatmentstatus    -0.0302     0.0040    -7.6042     0.0000     -0.0380     -0.0224
# ===================================================================================
#
# F-test for Poolability: 66.370
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 7
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0151
# Estimator:                   PanelOLS   R-squared (Between):              0.0038
# No. Observations:                7824   R-squared (Within):              -0.0039
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0037
# Time:                        17:14:30   Log-likelihood                 1.557e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      59.746
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             59.746
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.2676     0.0006     479.34     0.0000      0.2665      0.2687
# treatmentstatus    -0.0270     0.0035    -7.7296     0.0000     -0.0338     -0.0201
# ===================================================================================
#
# F-test for Poolability: 68.298
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 8
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0021
# Estimator:                   PanelOLS   R-squared (Between):              0.0018
# No. Observations:                7824   R-squared (Within):               0.0163
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0023
# Time:                        17:14:31   Log-likelihood                 1.691e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.1528
# Entities:                        3912   P-value                           0.0043
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             8.1528
#                                         P-value                           0.0043
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.2440     0.0005     518.71     0.0000      0.2431      0.2449
# treatmentstatus    -0.0084     0.0029    -2.8553     0.0043     -0.0142     -0.0026
# ===================================================================================
#
# F-test for Poolability: 59.546
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 9
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0139
# Estimator:                   PanelOLS   R-squared (Between):              0.0086
# No. Observations:                7824   R-squared (Within):               0.0461
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0110
# Time:                        17:14:31   Log-likelihood                  1.44e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      55.086
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             55.086
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.3770     0.0006     581.65     0.0000      0.3757      0.3783
# treatmentstatus    -0.0301     0.0040    -7.4220     0.0000     -0.0380     -0.0221
# ===================================================================================
#
# F-test for Poolability: 23.035
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 10
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0101
# Estimator:                   PanelOLS   R-squared (Between):              0.0068
# No. Observations:                7824   R-squared (Within):               0.0285
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0086
# Time:                        17:14:32   Log-likelihood                 1.213e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      39.946
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             39.946
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.6113     0.0009     704.91     0.0000      0.6096      0.6130
# treatmentstatus    -0.0342     0.0054    -6.3203     0.0000     -0.0449     -0.0236
# ===================================================================================
#
# F-test for Poolability: 12.304
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 11
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0047
# Estimator:                   PanelOLS   R-squared (Between):              0.0036
# No. Observations:                7824   R-squared (Within):              -0.0017
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0032
# Time:                        17:14:33   Log-likelihood                  1.24e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      18.495
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             18.495
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.7343     0.0008     876.70     0.0000      0.7327      0.7360
# treatmentstatus    -0.0225     0.0052    -4.3006     0.0000     -0.0328     -0.0122
# ===================================================================================
#
# F-test for Poolability: 14.091
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# For month 12
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      L   R-squared:                        0.0034
# Estimator:                   PanelOLS   R-squared (Between):              0.0035
# No. Observations:                7824   R-squared (Within):               0.0038
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0035
# Time:                        17:14:33   Log-likelihood                 1.261e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      13.382
# Entities:                        3912   P-value                           0.0003
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             13.382
#                                         P-value                           0.0003
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               0.8444     0.0008     1036.5     0.0000      0.8428      0.8460
# treatmentstatus    -0.0186     0.0051    -3.6581     0.0003     -0.0286     -0.0086
# ===================================================================================
#
# F-test for Poolability: 8.6356
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time

# %%
# read forest loss data
loss = pd.read_csv('data/hansen/loss.csv')
loss['id'] = loss['id'].astype(str)


GBApre = GBA.loc[pre[0]:pre[1]].groupby(level=[1]).mean().T
GBApre['id'] = GBApre.index
GBApre['post'] = 0
GBApre = GBApre.merge(loss, left_on='id', right_on='id', how='left'
                      ).melt(id_vars=['id','post', 'treated'], value_name='A', var_name='month')


GBApost = GBA.loc[post[0]:post[1]].groupby(level=[1]).mean().T
GBApost['id'] = GBApost.index
GBApost['post'] = 1
GBApost = GBApost.merge(loss, left_on='id', right_on='id', how='left'
                       ).melt(id_vars=['id','post', 'treated'], value_name='A', var_name='month')
tofit = pd.concat([GBApost, GBApre])
x1 = tofit.post.values
x2 = tofit.treated.values
tofit['treatmentstatus'] = 0
tofit['treatmentstatus'] = x2*x1
tofit = tofit.set_index(['id', 'post'])



for g in tofit.groupby('month'):
    mi_data = pd.DataFrame(g[1])
    exog_vars = ['treatmentstatus']
    exog = sm.add_constant(mi_data[exog_vars])
    mod = PanelOLS(mi_data.A, exog, entity_effects=True, time_effects=True)
    print('\n\n+++++++++++++++++++++\n+++++++++++++++++++++\nFor month %s \n'%(str(g[0])))
    print(mod.fit())
# Out:
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 1
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                     7.736e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0007
# No. Observations:                7824   R-squared (Within):              -0.0002
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0006
# Time:                        17:13:58   Log-likelihood                   -9202.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.3025
# Entities:                        3912   P-value                           0.5823
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             0.3025
#                                         P-value                           0.5823
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               10.403     0.0132     785.53     0.0000      10.377      10.429
# treatmentstatus    -0.0455     0.0827    -0.5500     0.5823     -0.2077      0.1167
# ===================================================================================
#
# F-test for Poolability: 4.1687
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 2
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                     3.522e-05
# Estimator:                   PanelOLS   R-squared (Between):              0.0006
# No. Observations:                7824   R-squared (Within):               0.0006
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0006
# Time:                        17:13:59   Log-likelihood                   -9750.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.1377
# Entities:                        3912   P-value                           0.7106
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             0.1377
#                                         P-value                           0.7106
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               10.791     0.0142     759.72     0.0000      10.763      10.819
# treatmentstatus     0.0329     0.0887     0.3711     0.7106     -0.1410      0.2069
# ===================================================================================
#
# F-test for Poolability: 4.1469
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 3
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0013
# Estimator:                   PanelOLS   R-squared (Between):             -0.0027
# No. Observations:                7824   R-squared (Within):              -0.0025
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0027
# Time:                        17:13:59   Log-likelihood                   -9810.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.9788
# Entities:                        3912   P-value                           0.0257
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             4.9788
#                                         P-value                           0.0257
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               10.393     0.0143     726.15     0.0000      10.365      10.421
# treatmentstatus    -0.1995     0.0894    -2.2313     0.0257     -0.3748     -0.0242
# ===================================================================================
#
# F-test for Poolability: 4.7985
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 4
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0011
# Estimator:                   PanelOLS   R-squared (Between):          -6.677e-05
# No. Observations:                7824   R-squared (Within):               0.0030
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0004
# Time:                        17:14:00   Log-likelihood                -1.043e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.3059
# Entities:                        3912   P-value                           0.0380
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             4.3059
#                                         P-value                           0.0380
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               9.3098     0.0155     601.03     0.0000      9.2795      9.3402
# treatmentstatus     0.2008     0.0968     2.0751     0.0380      0.0111      0.3905
# ===================================================================================
#
# F-test for Poolability: 6.2524
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 5
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0033
# Estimator:                   PanelOLS   R-squared (Between):             -0.0022
# No. Observations:                7824   R-squared (Within):               0.0099
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0006
# Time:                        17:14:01   Log-likelihood                -1.067e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      12.832
# Entities:                        3912   P-value                           0.0003
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             12.832
#                                         P-value                           0.0003
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               7.5649     0.0160     473.34     0.0000      7.5336      7.5962
# treatmentstatus     0.3576     0.0998     3.5822     0.0003      0.1619      0.5534
# ===================================================================================
#
# F-test for Poolability: 6.8162
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 6
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0020
# Estimator:                   PanelOLS   R-squared (Between):             -0.0032
# No. Observations:                7824   R-squared (Within):               0.0007
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0023
# Time:                        17:14:01   Log-likelihood                -1.274e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.8421
# Entities:                        3912   P-value                           0.0051
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             7.8421
#                                         P-value                           0.0051
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               6.2964     0.0208     302.48     0.0000      6.2556      6.3372
# treatmentstatus     0.3641     0.1300     2.8004     0.0051      0.1092      0.6191
# ===================================================================================
#
# F-test for Poolability: 3.2765
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
# /Users/daviddralle/anaconda2/envs/gr3/lib/python3.5/site-packages/linearmodels/utility.py:490: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 7
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0033
# Estimator:                   PanelOLS   R-squared (Between):             -0.0030
# No. Observations:                7555   R-squared (Within):              -0.0011
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0027
# Time:                        17:14:02   Log-likelihood                -1.293e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      11.945
# Entities:                        3911   P-value                           0.0006
# Avg Obs:                       1.9317   Distribution:                  F(1,3642)
# Min Obs:                       1.0000
# Max Obs:                       2.0000   F-statistic (robust):             11.945
#                                         P-value                           0.0006
# Time periods:                       2   Distribution:                  F(1,3642)
# Avg Obs:                       3777.5
# Min Obs:                       3644.0
# Max Obs:                       3911.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               5.7348     0.0234     245.14     0.0000      5.6889      5.7806
# treatmentstatus     0.5135     0.1486     3.4561     0.0006      0.2222      0.8048
# ===================================================================================
#
# F-test for Poolability: 2.6474
# P-value: 0.0000
# Distribution: F(3911,3642)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 8
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0020
# Estimator:                   PanelOLS   R-squared (Between):             -0.0015
# No. Observations:                7804   R-squared (Within):              -0.0018
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0015
# Time:                        17:14:03   Log-likelihood                -1.224e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.9181
# Entities:                        3912   P-value                           0.0049
# Avg Obs:                       1.9949   Distribution:                  F(1,3890)
# Min Obs:                       1.0000
# Max Obs:                       2.0000   F-statistic (robust):             7.9181
#                                         P-value                           0.0049
# Time periods:                       2   Distribution:                  F(1,3890)
# Avg Obs:                       3902.0
# Min Obs:                       3892.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               5.8018     0.0197     295.17     0.0000      5.7633      5.8404
# treatmentstatus     0.3460     0.1230     2.8139     0.0049      0.1049      0.5870
# ===================================================================================
#
# F-test for Poolability: 3.0236
# P-value: 0.0000
# Distribution: F(3912,3890)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 9
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.0003
# No. Observations:                7824   R-squared (Within):              -0.0010
# Date:                Mon, Apr 02 2018   R-squared (Overall):             -0.0005
# Time:                        17:14:03   Log-likelihood                -1.138e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.7441
# Entities:                        3912   P-value                           0.0977
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             2.7441
#                                         P-value                           0.0977
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               6.2543     0.0175     357.69     0.0000      6.2200      6.2886
# treatmentstatus     0.1809     0.1092     1.6565     0.0977     -0.0332      0.3951
# ===================================================================================
#
# F-test for Poolability: 3.8456
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 10
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0085
# Estimator:                   PanelOLS   R-squared (Between):             -0.0009
# No. Observations:                7824   R-squared (Within):               0.0037
# Date:                Mon, Apr 02 2018   R-squared (Overall):          -2.855e-06
# Time:                        17:14:04   Log-likelihood                -1.156e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      33.633
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             33.633
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               7.2551     0.0179     405.50     0.0000      7.2200      7.2902
# treatmentstatus     0.6482     0.1118     5.7994     0.0000      0.4291      0.8673
# ===================================================================================
#
# F-test for Poolability: 3.9280
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 11
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0107
# Estimator:                   PanelOLS   R-squared (Between):              0.0001
# No. Observations:                7824   R-squared (Within):               0.0077
# Date:                Mon, Apr 02 2018   R-squared (Overall):              0.0015
# Time:                        17:14:05   Log-likelihood                -1.074e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.422
# Entities:                        3912   P-value                           0.0000
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             42.422
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               8.3042     0.0161     515.20     0.0000      8.2726      8.3358
# treatmentstatus     0.6558     0.1007     6.5132     0.0000      0.4584      0.8532
# ===================================================================================
#
# F-test for Poolability: 4.6690
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time
#
#
# +++++++++++++++++++++
# +++++++++++++++++++++
# For month 12
#
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                      A   R-squared:                        0.0012
# Estimator:                   PanelOLS   R-squared (Between):              0.0008
# No. Observations:                7824   R-squared (Within):              -0.0037
# Date:                Mon, Apr 02 2018   R-squared (Overall):          -9.156e-05
# Time:                        17:14:05   Log-likelihood                   -9984.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.7949
# Entities:                        3912   P-value                           0.0286
# Avg Obs:                       2.0000   Distribution:                  F(1,3910)
# Min Obs:                       2.0000
# Max Obs:                       2.0000   F-statistic (robust):             4.7949
#                                         P-value                           0.0286
# Time periods:                       2   Distribution:                  F(1,3910)
# Avg Obs:                       3912.0
# Min Obs:                       3912.0
# Max Obs:                       3912.0
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               9.4748     0.0146     647.40     0.0000      9.4461      9.5035
# treatmentstatus     0.2002     0.0914     2.1897     0.0286      0.0210      0.3794
# ===================================================================================
#
# F-test for Poolability: 4.4884
# P-value: 0.0000
# Distribution: F(3912,3910)
#
# Included effects: Entity, Time

# %%
from linearmodels import PanelOLS
test = pd.DataFrame.from_dict({0:Ss[0,:], 1:Ss[1,:]})
test['treated'] = np.random.randint(0,2,len(test))
test['id'] = df.columns
tofit = test.melt(value_vars = [0, 1], id_vars = ['treated', 'id'])
tofit['treatmentstatus'] = tofit.treated*tofit.variable
tofit = tofit.set_index(['id', 'variable'])
res = PanelOLS(tofit.value, tofit.treatmentstatus, entity_effects=True, time_effects=True).fit()
print(res)
